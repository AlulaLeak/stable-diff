# %% [markdown]
# Hey friends! Try art-based AI with a few clicks in this notebook :)
#
# ---------
#
# **BEFORE YOU START:**
#
# Check to see if a GPU is being used.
#
# In the top right of this notebook, click on:
# Runtime -> Change Runtime Type
# and change the "Hardware Accelorator" from "None" to "GPU".
#
# ---------
#
# **AND THEN:**
#
# Just click on each of the play buttons that appear while hovering the code boxes below.
#
# !! READ THE GREEN TEXTS TO KNOW WHERE TO INPUT YOUR ART REQUESTS !!
#
# ---------
#
# The png image will appear in your google drive in the newly created "stable_diffusion" folder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install --upgrade diffusers
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 153 kB 33.7 MB/s
# ...
#      |████████████████████████████████| 120 kB 68.5 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.9 MB 27.7 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 52.8 MB/s
# ...

# %%
import subprocess
from torch import autocast
from diffusers import StableDiffusionPipeline
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", use_auth_token="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")
pipe = pipe.to("cuda")
# Out:
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4fc76f3fc0c0> in <module>
# ----> 1 pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", use_auth_token="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")
#       2 pipe = pipe.to("cuda")
#
# /usr/local/lib/python3.7/dist-packages/diffusers/pipeline_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     293                 local_files_only=local_files_only,
#     294                 use_auth_token=use_auth_token,
# ...

# %%
#  REPLACE THE TEXT INSIDE OF THE QUOTES WITH WHAT YOU WANT TO SEE
prompt = "a gorilla as a war general. 90's themed"

#  REPLACE THE TEXT INSIDE OF THE QUOTES WITH WHAT YOU WANT TO NAME YOUR IMAGE FILE
image_name = "90s_war_gorilla"

# %%
with autocast("cuda"):
    image1 = pipe(prompt).images[0]
    image2 = pipe(prompt).images[0]
    image3 = pipe(prompt).images[0]
    image4 = pipe(prompt).images[0]

# %%
subprocess.run(f"cd drive/MyDrive && mkdir stable_diffusion/{image_name} && cd stable_diffusion/{image_name}", shell=True)

# %%
image1.save(f"./drive/MyDrive/stable_diffusion/{image_name}/{image_name}1.png")
image2.save(f"./drive/MyDrive/stable_diffusion/{image_name}/{image_name}2.png")
image3.save(f"./drive/MyDrive/stable_diffusion/{image_name}/{image_name}3.png")
image4.save(f"./drive/MyDrive/stable_diffusion/{image_name}/{image_name}4.png")
